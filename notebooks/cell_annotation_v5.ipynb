# %%
import json
import os
from pathlib import Path

import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import tifffile
from einops import rearrange

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
df = pd.read_csv('../examples/test/output.txt', sep='\t')
df
# Out:
#       label          row          col  bbox-r1  bbox-c1  bbox-r2  bbox-c2  \
# 0         1     3.633333   148.240000        0      138       10      160
# 1         2     1.823529   162.970588        0      160        5      168
# 2         3     2.000000   102.396226        0       96        6      108
# 3         4     3.444444   475.388889        2      473        7      478
# 4         5     3.177215   551.468354        0      545        9      557
# ...     ...          ...          ...      ...      ...      ...      ...
# 4328   4329  1996.283951  1560.197531     1992     1554     2000     1568
# 4329   4330  1995.263736  1624.560440     1991     1619     2000     1631
# 4330   4331  1996.321839   669.436782     1993      662     2000      677
# 4331   4332  1996.724138  1353.534483     1994     1348     2000     1361
# 4332   4333  1996.217949  1820.243590     1993     1814     2000     1827
#
#       area  CD11c_intensity  CD11c_intensity_scaled  ...  \
# ...

# %%
sns.scatterplot(data=df, x='col', y='row', hue='cell_type')
# Out:
# <Axes: xlabel='col', ylabel='row'>

# %%
# !pip freeze | egrep 'tornado'
# Out:
# tornado==6.3.2
