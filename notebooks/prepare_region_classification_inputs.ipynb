# %%
import math
import os
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scanpy as sc
import seaborn as sns
import tifffile
import torchvision.transforms.functional as TF
import torch
from pathlib import Path
from collections import Counter

from einops import rearrange

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
from mip.utils import listfiles, extract_ome_tiff, R_CHANNEL_MAPPING, make_pseudo, display_region

# %%
out_dir = '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/classification'
Path(out_dir).mkdir(parents=True, exist_ok=True)

# %%
fps = sorted(listfiles('/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2',
                      regex=r'.pt$'))
fps
# Out:
# ['/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT110B1_S1H4_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT171B1-S1H9A1-4_left_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT171B1-S1H9A1-4_right_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT206B1_H1_06252022_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT206B1_H1_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT206B1_S1H2L4_20221028_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT243B1-S1H4A4_04192023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT243B1-S1H4A4_left_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT243B1-S1H4A4_right_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT243B1_S1H4_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT271B1-S1H6A5_04192023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT271B1-S1H6A5_left_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT271B1-S1H6A5_right_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT297B1_H1_08042022_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT305B1_S1H1_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT308B1-S1H5A4_04192023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT308B1-S1H5A4_left_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT308B1-S1H5A4_right_05122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT323B1_H1A1_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT323B1_H1A4_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT323B1_H1_08042022_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT323B1_H3_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT339B1_H1A1_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT339B1_H2A1_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT339B1_H4A4_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT365B1_S1H1_02132023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT397B1_H2A2_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT397B1_H3A1_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT397B1_S1H1A3U22_04122023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT397B1_S1H1A3U31_04062023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT397B1_U12_03172023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT397B1_U2_03162023_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT480B1_S1H2_R001_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT480B1_S1H2_R002_results.pt',
#  '/diskmnt/Projects/Users/estorrs/multiplex_data/analysis/brca_dcis_v2/region_analysis_v2/HT565B1-H2_04262023_results.pt']

# %%
sample_to_tables = {}
sample_to_thumbnail = {}
for fp in fps:
    sample = fp.split('/')[-1].split('_results')[0]
    print(sample)
    
    obj = torch.load(fp)
    sample_to_tables[sample] = obj['tables']
    sample_to_thumbnail[sample] = obj['images']['thumbnail']['pseudo']
sample_to_tables.keys()
# Out:
# HT110B1_S1H4
# HT171B1-S1H9A1-4_left_05122023
# HT171B1-S1H9A1-4_right_05122023
# HT206B1_H1_06252022
# HT206B1_H1
# HT206B1_S1H2L4_20221028
# HT243B1-S1H4A4_04192023
# HT243B1-S1H4A4_left_05122023
# HT243B1-S1H4A4_right_05122023
# HT243B1_S1H4
# HT271B1-S1H6A5_04192023
# HT271B1-S1H6A5_left_05122023
# HT271B1-S1H6A5_right_05122023
# HT297B1_H1_08042022
# HT305B1_S1H1
# HT308B1-S1H5A4_04192023
# HT308B1-S1H5A4_left_05122023
# HT308B1-S1H5A4_right_05122023
# HT323B1_H1A1
# HT323B1_H1A4
# HT323B1_H1_08042022
# HT323B1_H3
# HT339B1_H1A1
# HT339B1_H2A1
# HT339B1_H4A4
# HT365B1_S1H1_02132023
# HT397B1_H2A2
# HT397B1_H3A1
# HT397B1_S1H1A3U22_04122023
# HT397B1_S1H1A3U31_04062023
# HT397B1_U12_03172023
# HT397B1_U2_03162023
# HT480B1_S1H2_R001
# HT480B1_S1H2_R002
# HT565B1-H2_04262023
# dict_keys(['HT110B1_S1H4', 'HT171B1-S1H9A1-4_left_05122023', 'HT171B1-S1H9A1-4_right_05122023', 'HT206B1_H1_06252022', 'HT206B1_H1', 'HT206B1_S1H2L4_20221028', 'HT243B1-S1H4A4_04192023', 'HT243B1-S1H4A4_left_05122023', 'HT243B1-S1H4A4_right_05122023', 'HT243B1_S1H4', 'HT271B1-S1H6A5_04192023', 'HT271B1-S1H6A5_left_05122023', 'HT271B1-S1H6A5_right_05122023', 'HT297B1_H1_08042022', 'HT305B1_S1H1', 'HT308B1-S1H5A4_04192023', 'HT308B1-S1H5A4_left_05122023', 'HT308B1-S1H5A4_right_05122023', 'HT323B1_H1A1', 'HT323B1_H1A4', 'HT323B1_H1_08042022', 'HT323B1_H3', 'HT339B1_H1A1', 'HT339B1_H2A1', 'HT339B1_H4A4', 'HT365B1_S1H1_02132023', 'HT397B1_H2A2', 'HT397B1_H3A1', 'HT397B1_S1H1A3U22_04122023', 'HT397B1_S1H1A3U31_04062023', 'HT397B1_U12_03172023', 'HT397B1_U2_03162023', 'HT480B1_S1H2_R001', 'HT480B1_S1H2_R002', 'HT565B1-H2_04262023'])

# %%
type_to_combined = {}
for k in next(iter(sample_to_table.values())).keys():
    combined = None
    for s, tables in sample_to_table.items():
        df = tables[k].copy()
        df.index = [f'{s}_{x}' for x in df.index]
        df.index.name = 'label'
        df['sample'] = s

        df = df.transpose()

        if combined is None:
            combined = df
        else:
            combined = pd.merge(combined, df, left_index=True, right_index=True, how='outer')
    combined = combined.transpose()
    combined.index.name = 'label'
    type_to_combined[k] = combined
# Out:
#                            area    c1     c2 cell_type_fraction_B cell  \
# label
# HT110B1_S1H4_1            15584  4569   4678                       0.0
# HT110B1_S1H4_2           124527  5316   5801                       0.0
# HT110B1_S1H4_3            53376  6320   6584                       0.0
# HT110B1_S1H4_4            27860  5989   6171                       0.0
# HT110B1_S1H4_5            11164  4968   5059                       0.0
# ...                         ...   ...    ...                       ...
# HT565B1-H2_04262023_104   93531  5207   5732                       NaN
# HT565B1-H2_04262023_105   17642  8658   8822                       NaN
# HT565B1-H2_04262023_106  346698  3721   5114                       NaN
# HT565B1-H2_04262023_107  221671  9054  10267                       NaN
# HT565B1-H2_04262023_108   10961  6102   6249                       NaN
#
#                         cell_type_fraction_CD4 T cell  \
# label
# HT110B1_S1H4_1                                    NaN
# HT110B1_S1H4_2                                    NaN
# HT110B1_S1H4_3                                    NaN
# HT110B1_S1H4_4                                    NaN
# HT110B1_S1H4_5                                    NaN
# ...                                               ...
# HT565B1-H2_04262023_104                           0.0
# HT565B1-H2_04262023_105                           0.1
# HT565B1-H2_04262023_106                      0.004525
# HT565B1-H2_04262023_107                           0.0
# HT565B1-H2_04262023_108                           0.0
#
#                         cell_type_fraction_CD8 T cell  \
# label
# HT110B1_S1H4_1                                    0.0
# HT110B1_S1H4_2                               0.007194
# HT110B1_S1H4_3                                    0.0
# HT110B1_S1H4_4                                    0.0
# HT110B1_S1H4_5                                    0.0
# ...                                               ...
# HT565B1-H2_04262023_104                      0.011111
# HT565B1-H2_04262023_105                           0.4
# HT565B1-H2_04262023_106                      0.013575
# HT565B1-H2_04262023_107                           0.0
# HT565B1-H2_04262023_108                           0.0
#
#                         cell_type_fraction_Endothelial  \
# label
# HT110B1_S1H4_1                                     NaN
# HT110B1_S1H4_2                                     NaN
# HT110B1_S1H4_3                                     NaN
# HT110B1_S1H4_4                                     NaN
# HT110B1_S1H4_5                                     NaN
# ...                                                ...
# HT565B1-H2_04262023_104                       0.533333
# HT565B1-H2_04262023_105                       0.133333
# HT565B1-H2_04262023_106                       0.294118
# HT565B1-H2_04262023_107                            0.0
# HT565B1-H2_04262023_108                       0.578947
#
#                         cell_type_fraction_Epithelial  \
# label
# HT110B1_S1H4_1                                    1.0
# HT110B1_S1H4_2                               0.971223
# HT110B1_S1H4_3                               0.988095
# HT110B1_S1H4_4                               0.960784
# HT110B1_S1H4_5                                    1.0
# ...                                               ...
# HT565B1-H2_04262023_104                      0.355556
# HT565B1-H2_04262023_105                      0.366667
# HT565B1-H2_04262023_106                      0.597285
# HT565B1-H2_04262023_107                           1.0
# HT565B1-H2_04262023_108                      0.421053
#
#                         cell_type_fraction_Immune  \
# label
# HT110B1_S1H4_1                                0.0
# HT110B1_S1H4_2                           0.007194
# HT110B1_S1H4_3                                0.0
# HT110B1_S1H4_4                                0.0
# HT110B1_S1H4_5                                0.0
# ...                                           ...
# HT565B1-H2_04262023_104                  0.077778
# HT565B1-H2_04262023_105                       0.0
# HT565B1-H2_04262023_106                  0.081448
# HT565B1-H2_04262023_107                       0.0
# HT565B1-H2_04262023_108                       0.0
#
#                         cell_type_fraction_Macrophage - M1  ...  \
# label                                                       ...
# HT110B1_S1H4_1                                         0.0  ...
# HT110B1_S1H4_2                                         0.0  ...
# HT110B1_S1H4_3                                         0.0  ...
# HT110B1_S1H4_4                                         0.0  ...
# HT110B1_S1H4_5                                         0.0  ...
# ...                                                    ...  ...
# HT565B1-H2_04262023_104                                NaN  ...
# HT565B1-H2_04262023_105                                NaN  ...
# HT565B1-H2_04262023_106                                NaN  ...
# HT565B1-H2_04262023_107                                NaN  ...
# HT565B1-H2_04262023_108                                NaN  ...
#
#                         marker_intensity_TFF1 (D) marker_intensity_Vimentin  \
# label
# HT110B1_S1H4_1                                NaN                   2.21952
# HT110B1_S1H4_2                                NaN                 26.210075
# HT110B1_S1H4_3                                NaN                  10.42995
# HT110B1_S1H4_4                                NaN                 19.044903
# HT110B1_S1H4_5                                NaN                  7.892153
# ...                                           ...                       ...
# HT565B1-H2_04262023_104                 11.539308                124.236884
# HT565B1-H2_04262023_105                  9.869856                  38.46344
# HT565B1-H2_04262023_106                 12.282214                111.742361
# HT565B1-H2_04262023_107                  3.518999                 68.631034
# HT565B1-H2_04262023_108                  5.452696                179.288204
#
#                         marker_intensity_a-Amylase  \
# label
# HT110B1_S1H4_1                                 NaN
# HT110B1_S1H4_2                                 NaN
# HT110B1_S1H4_3                                 NaN
# HT110B1_S1H4_4                                 NaN
# HT110B1_S1H4_5                                 NaN
# ...                                            ...
# HT565B1-H2_04262023_104                   3.556094
# HT565B1-H2_04262023_105                   1.339191
# HT565B1-H2_04262023_106                   2.966143
# HT565B1-H2_04262023_107                   1.212657
# HT565B1-H2_04262023_108                   1.548764
#
#                         marker_intensity_beta-integrin marker_intensity_cKit  \
# label
# HT110B1_S1H4_1                                     NaN              1.924538
# HT110B1_S1H4_2                                     NaN              8.830077
# HT110B1_S1H4_3                                     NaN              4.571661
# HT110B1_S1H4_4                                     NaN              3.973439
# HT110B1_S1H4_5                                     NaN              3.456467
# ...                                                ...                   ...
# HT565B1-H2_04262023_104                            NaN              9.951129
# HT565B1-H2_04262023_105                            NaN              3.289196
# HT565B1-H2_04262023_106                            NaN             10.963692
# HT565B1-H2_04262023_107                            NaN              3.011224
# HT565B1-H2_04262023_108                            NaN              3.239485
#
#                            perimeter     r1     r2           row  \
# label
# HT110B1_S1H4_1            579.747258  13113  13332  13219.493134
# HT110B1_S1H4_2           2105.349422  15628  16169  15907.752656
# HT110B1_S1H4_3           1587.359523  15648  16080  15903.167697
# HT110B1_S1H4_4            911.327994  15910  16143  16024.476741
# HT110B1_S1H4_5            622.232539  15929  16133  16035.594411
# ...                              ...    ...    ...           ...
# HT565B1-H2_04262023_104  1918.278354  14329  14800  14569.474516
# HT565B1-H2_04262023_105   569.487373  14337  14511  14421.758247
# HT565B1-H2_04262023_106  4397.380951  14389  14800  14660.152256
# HT565B1-H2_04262023_107  3347.207286  14496  14800  14681.703633
# HT565B1-H2_04262023_108   561.279221  14672  14800   14718.77347
#
#                                       sample
# label
# HT110B1_S1H4_1                  HT110B1_S1H4
# HT110B1_S1H4_2                  HT110B1_S1H4
# HT110B1_S1H4_3                  HT110B1_S1H4
# HT110B1_S1H4_4                  HT110B1_S1H4
# HT110B1_S1H4_5                  HT110B1_S1H4
# ...                                      ...
# HT565B1-H2_04262023_104  HT565B1-H2_04262023
# HT565B1-H2_04262023_105  HT565B1-H2_04262023
# HT565B1-H2_04262023_106  HT565B1-H2_04262023
# HT565B1-H2_04262023_107  HT565B1-H2_04262023
# HT565B1-H2_04262023_108  HT565B1-H2_04262023
#
# [10766 rows x 101 columns]

# %%
samples = sorted(sample_to_tables.keys())
samples
# Out:
# ['HT110B1_S1H4',
#  'HT171B1-S1H9A1-4_left_05122023',
#  'HT171B1-S1H9A1-4_right_05122023',
#  'HT206B1_H1',
#  'HT206B1_H1_06252022',
#  'HT206B1_S1H2L4_20221028',
#  'HT243B1-S1H4A4_04192023',
#  'HT243B1-S1H4A4_left_05122023',
#  'HT243B1-S1H4A4_right_05122023',
#  'HT243B1_S1H4',
#  'HT271B1-S1H6A5_04192023',
#  'HT271B1-S1H6A5_left_05122023',
#  'HT271B1-S1H6A5_right_05122023',
#  'HT297B1_H1_08042022',
#  'HT305B1_S1H1',
#  'HT308B1-S1H5A4_04192023',
#  'HT308B1-S1H5A4_left_05122023',
#  'HT308B1-S1H5A4_right_05122023',
#  'HT323B1_H1A1',
#  'HT323B1_H1A4',
#  'HT323B1_H1_08042022',
#  'HT323B1_H3',
#  'HT339B1_H1A1',
#  'HT339B1_H2A1',
#  'HT339B1_H4A4',
#  'HT365B1_S1H1_02132023',
#  'HT397B1_H2A2',
#  'HT397B1_H3A1',
#  'HT397B1_S1H1A3U22_04122023',
#  'HT397B1_S1H1A3U31_04062023',
#  'HT397B1_U12_03172023',
#  'HT397B1_U2_03162023',
#  'HT480B1_S1H2_R001',
#  'HT480B1_S1H2_R002',
#  'HT565B1-H2_04262023']

# %%
sorted(type_to_combined['region'].columns)
# Out:
# ['area',
#  'c1',
#  'c2',
#  'cell_type_fraction_B cell',
#  'cell_type_fraction_CD4 T cell',
#  'cell_type_fraction_CD8 T cell',
#  'cell_type_fraction_Endothelial',
#  'cell_type_fraction_Epithelial',
#  'cell_type_fraction_Immune',
#  'cell_type_fraction_Macrophage - M1',
#  'cell_type_fraction_Stroma',
#  'cell_type_fraction_Treg',
#  'cell_type_fraction_Unlabeled',
#  'col',
#  'compactness',
#  'marker_fraction_CD11b',
#  'marker_fraction_CD163',
#  'marker_fraction_CD20',
#  'marker_fraction_CD31',
#  'marker_fraction_CD3e',
#  'marker_fraction_CD4',
#  'marker_fraction_CD45',
#  'marker_fraction_CD68',
#  'marker_fraction_CD8',
#  'marker_fraction_CK14',
#  'marker_fraction_CK17',
#  'marker_fraction_CK5',
#  'marker_fraction_E-cadherin',
#  'marker_fraction_FOXP3',
#  'marker_fraction_Ki67',
#  'marker_fraction_Pan-Cytokeratin',
#  'marker_fraction_Podoplanin',
#  'marker_fraction_SMA',
#  'marker_intensity_BCA1',
#  'marker_intensity_Bap1',
#  'marker_intensity_CD11b',
#  'marker_intensity_CD11c',
#  'marker_intensity_CD138',
#  'marker_intensity_CD163',
#  'marker_intensity_CD20',
#  'marker_intensity_CD31',
#  'marker_intensity_CD36',
#  'marker_intensity_CD3e',
#  'marker_intensity_CD4',
#  'marker_intensity_CD44',
#  'marker_intensity_CD45',
#  'marker_intensity_CD45RA',
#  'marker_intensity_CD68',
#  'marker_intensity_CD8',
#  'marker_intensity_CK14',
#  'marker_intensity_CK17',
#  'marker_intensity_CK19',
#  'marker_intensity_CK5',
#  'marker_intensity_COX2',
#  'marker_intensity_COX6c',
#  'marker_intensity_CTLA4',
#  'marker_intensity_DAPI',
#  'marker_intensity_E-cadherin',
#  'marker_intensity_ER',
#  'marker_intensity_FGFR3',
#  'marker_intensity_FOXP3',
#  'marker_intensity_GATA3',
#  'marker_intensity_GATA3 (D)',
#  'marker_intensity_GLUT1',
#  'marker_intensity_GLUT1 (D)',
#  'marker_intensity_GP2',
#  'marker_intensity_HIF1a',
#  'marker_intensity_HLA-DR',
#  'marker_intensity_Hep-Par-1 (D)',
#  'marker_intensity_Her2',
#  'marker_intensity_Histone H3 Pho',
#  'marker_intensity_Histone H3 Phospho (Ser28)',
#  'marker_intensity_Ki67',
#  'marker_intensity_Lyve-1',
#  'marker_intensity_MGP',
#  'marker_intensity_MLPH',
#  'marker_intensity_MMP9',
#  'marker_intensity_Maspin',
#  'marker_intensity_P16',
#  'marker_intensity_P21',
#  'marker_intensity_P63',
#  'marker_intensity_PD-1',
#  'marker_intensity_PD-L1',
#  'marker_intensity_PLAT/tPA',
#  'marker_intensity_PR',
#  'marker_intensity_PR (D)',
#  'marker_intensity_Pan-Cytokeratin',
#  'marker_intensity_Podoplanin',
#  'marker_intensity_SLC39A6',
#  'marker_intensity_SMA',
#  'marker_intensity_TFF1',
#  'marker_intensity_TFF1 (D)',
#  'marker_intensity_Vimentin',
#  'marker_intensity_a-Amylase',
#  'marker_intensity_beta-integrin',
#  'marker_intensity_cKit',
#  'perimeter',
#  'r1',
#  'r2',
#  'row',
#  'sample']

# %%
col = ''
sample_to_normal = {}
for sample in samples:
